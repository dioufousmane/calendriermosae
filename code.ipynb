# %%
import unicodedata
import pytz
import requests
from ics import Calendar
from datetime import datetime
import json
import re

# 🔗 Liens ICS et fichiers de sortie
CALENDARS = [
    {
        "name": "UNIV",
        "url": "http://planning.univ-lemans.fr/jsp/custom/modules/plannings/anonymous_cal.jsp?resources=7209&projectId=08&calType=ical&nbWeeks=52",
        "output": "univ_events.json"
    },
    {
        "name": "UNIV2",
        "url": "http://planning.univ-lemans.fr/jsp/custom/modules/plannings/anonymous_cal.jsp?resources=809&projectId=08&calType=ical&nbWeeks=52",
        "output": "univ_events2.json"
    }
]

TIMEZONE = pytz.timezone("Europe/Paris")
jours_fr = ["Lundi", "Mardi", "Mercredi", "Jeudi", "Vendredi", "Samedi", "Dimanche"]

formations_regex = r"""
    (?:M\d?\s+)?                  
    (MOSAE|URBANISTIC|MATTERRE|MIDEC|
     VILLE\s+ET\s+ENVIRONNEMENT[S]*\s*URBAIN[S]*|
     GEOGRAPHIE.*?DEVELOPPEMENT|
     HISTOIRE.*?PATRIMOINE|
     DDL.*?|LEA.*?|MEEF.*?|
     LP.*?|UEO.*?)
"""

# ----------------------------------------------------------
# UTILITAIRES
# ----------------------------------------------------------

def clean_text(text):
    if not text:
        return ""
    text = unicodedata.normalize("NFC", text)
    return text.replace("\n", " ").replace("\r", "").strip()

def extract_title(raw_title):
    line = raw_title.split("\\n")[0].strip()
    line = re.sub(r"^\s*\d+(?=\s*(TD|TP|CM)\b)", "", line, flags=re.IGNORECASE)
    line = re.sub(r"^\s*G\d+\s+", "", line, flags=re.IGNORECASE)
    line = re.sub(formations_regex, "", line, flags=re.IGNORECASE | re.VERBOSE).strip()
    return line

# ----------------------------------------------------------
# EXTRACTION ENSEIGNANT + SALLE DESCRIPTIONS ADE
# ----------------------------------------------------------

def extract_enseignant_and_salle(description, fallback_title=None):
    """
    Analyse ligne par ligne :
      HIVERT      ← enseignant
      C100        ← salle
      MOSAE...
    """
    if not description:
        return "non renseigné", "non renseignée"

    # Découpe en lignes propres
    lines = [l.strip() for l in description.splitlines() if l.strip()]

    enseignant = None
    salle = None

    for i, line in enumerate(lines):

        # Ligne = nom enseignant (MAJ, lettres, espaces et - )
        if re.fullmatch(r"[A-ZÉÈÊÎÛÀÄÖÜ\- ]{3,}", line):
            enseignant = line.title()  # HIVERT → Hivert
            # ligne suivante = salle ?
            if i + 1 < len(lines):
                next_line = lines[i+1]
                # Salle du style C100, B203, L12...
                if re.fullmatch(r"[A-Za-z]\d{2,4}", next_line):
                    salle = next_line.upper()
            break

    return enseignant or "non renseigné", salle or "non renseignée"

# ----------------------------------------------------------
# FALLBACK : REGEX SALLE GÉNÉRIQUE
# ----------------------------------------------------------

def extract_salle_fallback(description):
    if not description:
        return "non renseignée"

    desc = description.strip()

    labels = [
        "Salle", "Amphi", "Amphithéâtre",
        "Bâtiment", "Salle informatique"
    ]
    label_regex = "|".join([re.escape(l) for l in labels])

    # Format propre : Label + code court
    m = re.search(
        rf"\b(?P<label>{label_regex})\b\s*(?P<code>[A-Za-z0-9][A-Za-z0-9\-./_]{{0,8}})",
        desc,
        re.IGNORECASE
    )

    if m:
        label = m.group("label")
        code = m.group("code").upper()
        if label.lower() == "salle informatique":
            return f"Salle informatique {code}"
        return f"{label.capitalize()} {code}"

    # fallback plus large
    m2 = re.search(
        rf"\b({label_regex})\b\s*([^\n,();—-]{{1,80}})",
        desc,
        flags=re.IGNORECASE
    )
    if m2:
        segment = m2.group(0).strip()
        segment = re.split(r"[,(;—]|  {2,}", segment)[0].strip()
        segment = re.sub(r"\b([A-ZÉÈÊÛÎ]{2,}(?:\s+[A-ZÉÈÊÛÎ]{2,})*)", "", segment).strip()
        return segment[:40] or "non renseignée"

    return "non renseignée"

# ----------------------------------------------------------
# FORMATAGE FINAL
# ----------------------------------------------------------

def format_event(event, maj_str):
    dtstart_utc = event.begin.datetime.replace(tzinfo=pytz.UTC)
    dtend_utc = event.end.datetime.replace(tzinfo=pytz.UTC)

    dtstart = dtstart_utc.astimezone(TIMEZONE)
    dtend = dtend_utc.astimezone(TIMEZONE)

    day = jours_fr[dtstart.weekday()]
    date_str = dtstart.strftime("%d/%m/%Y")
    start_str = dtstart.strftime("%H:%M")
    end_str = dtend.strftime("%H:%M")

    raw_title = clean_text(event.name or "Sans titre")
    description = event.description or ""
    location = clean_text(event.location or "")

    title = extract_title(raw_title)

    # Extraction enseignant + salle ADE
    enseignant, salle_detectee = extract_enseignant_and_salle(description, title)

    # Salle fallback regex
    salle = salle_detectee
    if salle == "non renseignée":
        salle = extract_salle_fallback(description)

    # Cas spécial ESGT
    if salle == "non renseignée" and "salle esgt" in location.lower():
        salle = "Salle ESGT"

    return {
        "day": day,
        "date": date_str,
        "start": start_str,
        "end": end_str,
        "title": title,
        "salle": salle,
        "enseignant": enseignant,
        "maj": maj_str
    }

# ----------------------------------------------------------
# PROCESSUS GLOBAL
# ----------------------------------------------------------

def process_calendar(name, url, output_file):
    print(f"📡 Téléchargement du calendrier {name}...")
    response = requests.get(url)
    if response.status_code != 200:
        print(f"❌ Erreur {response.status_code} pour {name}")
        return

    calendar = Calendar(response.text)
    events = []

    maj_str = datetime.now(TIMEZONE).strftime("%d-%m-%Y %H:%M:%S")

    for event in calendar.events:
        if event.begin and event.end:
            dtstart = event.begin.datetime.astimezone(TIMEZONE)
            if dtstart.weekday() < 5:  # Lundi → Vendredi
                evt = format_event(event, maj_str)
                events.append(evt)
                print(f"✔️ {name} : {evt['title']} ({evt['date']} {evt['start']}-{evt['end']})")
            else:
                print(f"⏭️ {name} : Ignoré (weekend) : {event.name}")

    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(events, f, indent=2, ensure_ascii=False)

    print(f"✅ {len(events)} événements extraits pour {name}.")
    print(f"📄 Fichier généré : {output_file}\n")

def main():
    for cal in CALENDARS:
        process_calendar(cal["name"], cal["url"], cal["output"])

if __name__ == "__main__":
    main()
# Out:
# 📡 Téléchargement du calendrier UNIV...
# ✔️ UNIV : CONFERENCE COP - Territoire Durable et Neutralité Carbone (08/12/2025 09:30-17:30)
# ✔️ UNIV : TD LANGUE (15/12/2025 13:30-15:30)
# ✔️ UNIV : TD LANGUE (16/12/2025 13:30-15:30)
# ✔️ UNIV : 1 Jumeau numérique des territoires (23/01/2026 08:30-12:45)
# ✔️ UNIV : 1 Jumeau numérique des territoires (30/01/2026 08:30-12:45)
# ✔️ UNIV : TD Concevoir un observatoire de Territoires S.C. (09/12/2025 15:30-17:00)
# ✔️ UNIV : TD Concevoir un observatoire de Territoires S.C. (02/12/2025 15:30-17:00)
# ✔️ UNIV : 1 Initiation au Drone (14/01/2026 14:00-16:45)
# ✔️ UNIV : 1 Initiation au Drone (05/02/2026 08:30-12:45)
# ✔️ UNIV : 1 Initiation au Drone (05/02/2026 14:00-18:15)
# ✔️ UNIV : 1 Initiation au Drone (06/02/2026 14:00-18:15)
# ✔️ UNIV : 1 Initiation au Drone (06/02/2026 08:30-12:45)
# ✔️ UNIV : 1EXAMEN  - ESGT (04/02/2026 08:30-12:45)
# ✔️ UNIV : 1 Initiation au Drone (14/01/2026 08:30-12:45)
# ✔️ UNIV : CM SIG et Base de données (11/12/2025 14:00-16:45)
# ✔️ UNIV : TD Ville durable et changements climatiques (18/12/2025 13:30-15:30)
# ✔️ UNIV : CM Concevoir un observatoire de Territoires (09/12/2025 09:00-12:00)
# ✔️ UNIV : Photogrammétrie (04/12/2025 08:30-12:45)
# ✔️ UNIV : Photogrammétrie (04/12/2025 14:00-16:45)
# ✔️ UNIV : CHANTIER ECOLE - ESGT (10/12/2025 14:00-17:00)
# ✔️ UNIV : CM Transition énergetique urbaine et nature en ville (21/01/2026 13:30-16:30)
# ✔️ UNIV : TD Concevoir un observatoire de Territoires (13/01/2026 15:30-17:30)
# ✔️ UNIV : Atelier Futur Apprenti S. CHOLLET Formasup (02/02/2026 10:00-11:00)
# ✔️ UNIV : CM Concevoir un observatoire de Territoires (13/01/2026 13:30-15:30)
# ✔️ UNIV : TD Transition énergetique urbaine et nature en ville (03/02/2026 13:30-15:30)
# ✔️ UNIV : TD  Transition énergetique urbaine et nature en ville (27/01/2026 13:30-15:30)
# ✔️ UNIV : 1EXAMEN  - ESGT (04/02/2026 14:00-18:15)
# ✔️ UNIV : BIM (22/01/2026 08:30-11:15)
# ✔️ UNIV : BIM (21/01/2026 08:30-11:15)
# ✔️ UNIV : CHANTIER ECOLE - ESGT (02/12/2025 10:30-12:30)
# ✔️ UNIV : CM Analyse des Paysages et des Dynamiques Rurales - ESGT (16/01/2026 14:00-18:15)
# ✔️ UNIV : Photogrammétrie (03/12/2025 14:00-16:45)
# ✔️ UNIV : CM Analyse des Paysages et des Dynamiques Rurales - ESGT (07/01/2026 08:30-12:45)
# ✔️ UNIV : 1EXAMEN  - ESGT (12/12/2025 10:00-12:30)
# ✔️ UNIV : CM Analyse des Paysages et des Dynamiques Rurales - ESGT (16/01/2026 08:30-12:45)
# ✔️ UNIV : TD  Transition énergetique urbaine et nature en ville (26/01/2026 13:30-15:30)
# ✔️ UNIV : CM Transition énergetique urbaine et nature en ville (12/01/2026 13:30-16:30)
# ✔️ UNIV : Photogrammétrie (03/12/2025 08:30-12:45)
# ✔️ UNIV : CM Analyse des Paysages et des Dynamiques Rurales - ESGT (07/01/2026 14:00-18:15)
# ✔️ UNIV : 1 Jumeau numérique des territoires (23/01/2026 14:00-16:45)
# ✔️ UNIV : CM SIG et Base de données (10/12/2025 10:00-12:45)
# ✔️ UNIV : CM SIG et Base de données (11/12/2025 10:00-12:45)
# ✔️ UNIV : CM Concevoir un observatoire de Territoires (02/12/2025 13:30-15:30)
# ✔️ UNIV : BIM (13/01/2026 08:30-12:45)
# ✔️ UNIV : BIM (15/01/2026 08:30-12:45)
# ✔️ UNIV : CM Concevoir un observatoire de Territoires (09/12/2025 13:30-15:30)
# ✔️ UNIV : 1EXAMEN  - ESGT (12/12/2025 08:30-09:45)
# ✔️ UNIV : CM Concevoir un observatoire de Territoires (15/12/2025 10:00-12:00)
# ✅ 48 événements extraits pour UNIV.
# 📄 Fichier généré : univ_events.json
#
# 📡 Téléchargement du calendrier UNIV2...
# ✔️ UNIV2 : TD Acteurs, Enjeux et Politiques (09/12/2025 09:00-11:00)
# ✔️ UNIV2 : TD Acteurs, Enjeux et Politiques (09/12/2025 14:30-16:30)
# ✔️ UNIV2 : TD Retours d'expérience opérationnels (05/02/2026 13:30-16:30)
# ✔️ UNIV2 : TD Retours d'expérience opérationnels (14/01/2026 13:30-16:30)
# ✔️ UNIV2 : TD Retours d'expérience opérationnels (05/02/2026 16:30-17:30)
# ✔️ UNIV2 : TD Retours d'expérience opérationnels (05/02/2026 09:00-12:00)
# ✔️ UNIV2 : CM Construction d'un observatoire  PREPARATION (04/12/2025 09:00-12:30)
# ✔️ UNIV2 : CM Construction d'un observatoire  PREPARATION (05/12/2025 09:00-12:30)
# ✔️ UNIV2 : TD Acteurs, Enjeux et Politiques (08/12/2025 16:00-17:00)
# ✔️ UNIV2 : COURS à l'ESGT (13/01/2026 09:00-12:00)
# ✔️ UNIV2 : CM Construction d'un observatoire  PREPARATION (05/12/2025 14:00-17:30)
# ✔️ UNIV2 : DROIT AMENAGEMENT (04/12/2025 14:00-15:15)
# ✔️ UNIV2 : DROIT AMENAGEMENT (02/12/2025 08:30-12:45)
# ✔️ UNIV2 : CM Réalisation - Construction (05/01/2026 14:00-17:00)
# ✔️ UNIV2 : SIG WEB SIG SQL- ESGT (09/01/2026 10:00-13:00)
# ✔️ UNIV2 : SIG WEB SIG SQL- ESGT (12/12/2025 14:00-16:00)
# ✔️ UNIV2 : SIG WEB SIG SQL- ESGT (09/01/2026 14:00-16:00)
# ✔️ UNIV2 : SIG WEB SIG SQL- ESGT (12/12/2025 10:00-13:00)
# ✔️ UNIV2 : CM Réalisation - Construction (09/02/2026 13:30-16:30)
# ✔️ UNIV2 : TD Acteurs, Enjeux et Politiques (09/12/2025 13:30-14:30)
# ✔️ UNIV2 : TD Acteurs, Enjeux et Politiques (09/12/2025 11:00-12:00)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (18/02/2026 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (27/01/2026 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (29/01/2026 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (24/02/2026 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (25/02/2026 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (27/02/2026 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (23/02/2026 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (26/02/2026 08:30-20:30)
# ✔️ UNIV2 : TD Anglais technique et scientifique (12/01/2026 10:00-12:00)
# ✔️ UNIV2 : TD Anglais technique et scientifique (05/01/2026 10:30-12:30)
# ✔️ UNIV2 : Management/Asso Egée M2 VEU (14/01/2026 08:30-10:30)
# ✔️ UNIV2 : Management/Asso Egée M2 VEU (14/01/2026 10:30-12:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (16/12/2025 08:30-20:30)
# ✔️ UNIV2 : TD Anglais technique et scientifique (02/12/2025 15:30-17:30)
# ✔️ UNIV2 : TD Anglais technique et scientifique (05/01/2026 08:30-10:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (30/12/2025 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (26/01/2026 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (26/12/2025 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (15/12/2025 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (21/01/2026 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (02/01/2026 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (17/12/2025 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (23/12/2025 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (22/01/2026 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (19/12/2025 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (31/12/2025 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (19/01/2026 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (22/12/2025 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (24/12/2025 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (29/12/2025 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (20/01/2026 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (19/02/2026 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (23/01/2026 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (16/02/2026 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (28/01/2026 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (30/01/2026 08:30-20:30)
# ✔️ UNIV2 : 1PAO ILLUSTRATOR GRANGER- ESGT (10/12/2025 08:30-12:45)
# ✔️ UNIV2 : 1PAO ILLUSTRATOR GRANGER- ESGT (10/12/2025 14:00-16:45)
# ✔️ UNIV2 : 1PAO ILLUSTRATOR GRANGER- ESGT (15/01/2026 08:30-12:45)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (20/02/2026 08:30-20:30)
# ✔️ UNIV2 : CM MODELISATION 3D (16/01/2026 08:30-12:45)
# ✔️ UNIV2 : CM MODELISATION 3D (16/01/2026 14:00-16:45)
# ✔️ UNIV2 : CM MODELISATION 3D (15/01/2026 14:00-18:15)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (25/03/2026 09:00-21:00)
# ✔️ UNIV2 : TD Retours d'expérience opérationnels (02/02/2026 09:00-12:00)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (24/03/2026 09:00-21:00)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (23/03/2026 09:00-21:00)
# ✔️ UNIV2 : TD Retours d'expérience opérationnels (02/02/2026 13:30-16:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (19/12/2025 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (23/12/2025 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (16/03/2026 09:00-21:00)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (17/12/2025 08:30-20:30)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (20/03/2026 09:00-21:00)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (17/03/2026 09:00-21:00)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (19/03/2026 09:00-21:00)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (18/03/2026 09:00-21:00)
# ✔️ UNIV2 : TD Acteurs, Enjeux et Politiques (07/01/2026 09:00-12:00)
# ✔️ UNIV2 : Banalisé Altern. / Projets tutorés/ Stage annualisé (18/12/2025 08:30-20:30)
# ✔️ UNIV2 : TD Acteurs, Enjeux et Politiques (06/01/2026 09:00-12:00)
# ✔️ UNIV2 : 1DROIT AMENAGEMENT (11/12/2025 08:30-12:45)
# ✔️ UNIV2 : 1DROIT AMENAGEMENT (11/12/2025 13:45-16:30)
# ✔️ UNIV2 : TD Gestion de projets et de budget (03/12/2025 08:00-10:00)
# ✔️ UNIV2 : TD Gestion de projets et de budget (04/02/2026 09:00-11:00)
# ✔️ UNIV2 : TD Gestion de projets et de budget (04/02/2026 08:00-09:00)
# ✔️ UNIV2 : 1SIG WEB SIG SQL  - ESGT (06/02/2026 14:00-16:00)
# ✔️ UNIV2 : 1SIG WEB SIG SQL  - ESGT (06/02/2026 10:00-13:00)
# ✔️ UNIV2 : 1EXAMEN Anglais technique et scientifique (08/12/2025 08:00-10:00)
# ✔️ UNIV2 : CM Réalisation - Construction (03/02/2026 13:30-16:30)
# ✔️ UNIV2 : TD Acteurs, Enjeux et Politiques (08/12/2025 14:00-16:00)
# ✔️ UNIV2 : 1DROIT AMENAGEMENT (08/01/2026 14:00-16:45)
# ✔️ UNIV2 : 1DROIT AMENAGEMENT (08/01/2026 08:30-12:45)
# ✔️ UNIV2 : Banalisé  Altern. / Projets tutorés/ Stage annualisé (17/02/2026 08:30-20:30)
# ✔️ UNIV2 : TD Acteurs, Enjeux et Politiques (09/12/2025 13:30-16:30)
# ✔️ UNIV2 : TD Réalisation - Construction (08/12/2025 10:00-12:00)
# ✅ 95 événements extraits pour UNIV2.
# 📄 Fichier généré : univ_events2.json
